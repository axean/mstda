# %%
from rich import print
import random

# %%
ols_oeselma = """
 OEselma Silicon Count & 0.108439 & 0.004239 & 0.000530 & 0.003220 & 0.029690 \\
 OEselma Bromine Count & 0.265308 & 0.034856 & 0.032839 & 0.067323 & 0.253755 \\
 OEselma Iodine Count & 0.287843 & 0.028450 & 0.043962 & 0.074060 & 0.257294 \\
 OEselma Tsa & 261.688962 & 414.138860 & 416.314089 & 106.106942 & 0.405470 \\
 OEselma Rot Bond Count & 7.213711 & 6.681677 & 6.712394 & 2.944185 & 0.408137 \\
 OEselma Mol Volume 2D & 371.986946 & 592.330629 & 590.853288 & 157.692542 & 0.423920 \\
 OEselma Atom Count & 15.766603 & 25.429675 & 25.634004 & 7.037158 & 0.446333 \\
 OEselma Mw & 227.821937 & 373.328639 & 374.298888 & 104.350362 & 0.458035 \\
 OEselma Bond Count & 16.980448 & 26.935092 & 27.305614 & 7.864136 & 0.463129 \\
 OEselma Npsa & 200.207940 & 307.642466 & 312.725652 & 92.760671 & 0.463322 \\
 OEselma Carbon Count & 11.377305 & 17.636929 & 17.933263 & 5.364070 & 0.471471 \\
 OEselma Phosphorous Count & 0.474829 & 0.122751 & 0.123941 & 0.224827 & 0.473491 \\
 OEselma Part Flex Chain & 4.183248 & 4.829146 & 4.997881 & 2.108171 & 0.503955 \\
 OEselma Psa & 101.197251 & 106.494461 & 103.579013 & 52.274907 & 0.516564 \\
 OEselma Ertl Tpsa & 94.357347 & 102.704204 & 100.456871 & 49.051269 & 0.519846 \\
 OEselma Polar Count & 5.731492 & 6.059067 & 5.917903 & 3.004033 & 0.524128 \\
 OEselma Hba Lipinski & 5.725688 & 6.789826 & 6.721928 & 3.011111 & 0.525895 \\
 OEselma Fluorine Count & 0.933018 & 0.276967 & 0.297140 & 0.495503 & 0.531076 \\
 OEselma Rigid Frag Count & 3.579486 & 5.023363 & 5.022775 & 2.000506 & 0.558881 \\
 OEselma Hbd & 3.482418 & 2.674517 & 2.719809 & 1.948421 & 0.559502 \\
 OEselma Hbd Lipinski & 3.595447 & 2.940744 & 2.995763 & 2.017538 & 0.561137 \\
 OEselma Oxygen Count & 4.226225 & 4.206029 & 4.072034 & 2.389511 & 0.565401 \\
 OEselma Hba & 4.799591 & 5.812529 & 5.852754 & 2.729655 & 0.568727 \\
 OEselma Max Flex Chain 1 & 2.645862 & 2.943565 & 3.036547 & 1.515677 & 0.572848 \\
 OEselma Max Flex Chain 2 & 1.948082 & 1.691916 & 1.710275 & 1.116195 & 0.572972 \\
 OEselma Max Flex Chain 3 & 1.623217 & 1.148954 & 1.129237 & 0.932263 & 0.574331 \\
 OEselma Clorine Count & 0.515279 & 0.168629 & 0.181144 & 0.298271 & 0.578853 \\
 OEselma Neg Ioniz & 1.108872 & 0.539802 & 0.462394 & 0.650857 & 0.586955 \\
 OEselma Nitrogen Count & 2.861234 & 2.583797 & 2.649894 & 1.709653 & 0.597523 \\
 OEselma Rigid Bond Count & 10.405612 & 16.273575 & 16.576271 & 6.257895 & 0.601396 \\
 OEselma Nonpolar Count & 9.445993 & 12.086764 & 12.570445 & 5.846501 & 0.618940 \\
 OEselma Pos Ioniz & 1.323273 & 1.011211 & 1.046081 & 0.821974 & 0.621167 \\
 OEselma Ring Count & 1.811629 & 2.602073 & 2.675847 & 1.149428 & 0.634472 \\
 OEselma Halogen Count & 1.127074 & 0.508902 & 0.555085 & 0.739378 & 0.656016 \\
 OEselma Max Rigid Chain & 4.269220 & 6.990578 & 7.165254 & 2.869323 & 0.672095 \\
 OEselma Sulphur Count & 0.642512 & 0.289119 & 0.291843 & 0.442843 & 0.689237 \\
 OEselma Nonpolar Count Per Mw & 0.020729 & 0.031652 & 0.033239 & 0.015105 & 0.728698 \\
 OEselma Aromatic Ring Count & 1.351165 & 1.607348 & 1.683263 & 1.001529 & 0.741233 \\
 OEselma Polar Count Per Mw & 0.009170 & 0.016298 & 0.016026 & 0.006958 & 0.758783 \\
"""

# %%
cnn_oeselma = """
 OEselma Silicon Count & 0.108439 & 0.004239 & 0.001059 & 0.001745 & 0.016093 \\
 OEselma Iodine Count & 0.287843 & 0.028450 & 0.025953 & 0.029030 & 0.100853 \\
 OEselma Bromine Count & 0.265308 & 0.034856 & 0.034428 & 0.036573 & 0.137850 \\
 OEselma Phosphorous Count & 0.474829 & 0.122751 & 0.115466 & 0.118135 & 0.248795 \\
 OEselma Fluorine Count & 0.933018 & 0.276967 & 0.262712 & 0.267226 & 0.286411 \\
 OEselma Clorine Count & 0.515279 & 0.168629 & 0.160487 & 0.163946 & 0.318170 \\
 OEselma Neg Ioniz & 1.108872 & 0.539802 & 0.452860 & 0.457865 & 0.412911 \\
 OEselma Halogen Count & 1.127074 & 0.508902 & 0.483581 & 0.481674 & 0.427367 \\
 OEselma Sulphur Count & 0.642512 & 0.289119 & 0.280720 & 0.288122 & 0.448431 \\
 OEselma Part Flex Chain & 4.183248 & 4.829146 & 4.808263 & 1.967213 & 0.470260 \\
 OEselma Rot Bond Count & 7.213711 & 6.681677 & 6.401483 & 3.489025 & 0.483666 \\
 OEselma Npsa & 200.207940 & 307.642466 & 305.795517 & 98.622901 & 0.492602 \\
 OEselma Tsa & 261.688962 & 414.138860 & 405.405720 & 131.697137 & 0.503258 \\
 OEselma Oxygen Count & 4.226225 & 4.206029 & 3.956038 & 2.135425 & 0.505279 \\
 OEselma Hba & 4.799591 & 5.812529 & 5.663136 & 2.456341 & 0.511781 \\
 OEselma Mw & 227.821937 & 373.328639 & 362.211229 & 119.079400 & 0.522686 \\
 OEselma Hbd & 3.482418 & 2.674517 & 2.534958 & 1.830414 & 0.525616 \\
 OEselma Ertl Tpsa & 94.357347 & 102.704204 & 96.960223 & 50.082845 & 0.530778 \\
 OEselma Polar Count & 5.731492 & 6.059067 & 5.700212 & 3.074848 & 0.536483 \\
 OEselma Psa & 101.197251 & 106.494461 & 99.604419 & 54.736046 & 0.540885 \\
 OEselma Hbd Lipinski & 3.595447 & 2.940744 & 2.795021 & 1.959633 & 0.545032 \\
 OEselma Mol Volume 2D & 371.986946 & 592.330629 & 575.865486 & 204.456468 & 0.549633 \\
 OEselma Rigid Bond Count & 10.405612 & 16.273575 & 16.369703 & 5.730955 & 0.550756 \\
 OEselma Carbon Count & 11.377305 & 17.636929 & 17.591631 & 6.268767 & 0.550989 \\
 OEselma Hba Lipinski & 5.725688 & 6.789826 & 6.522246 & 3.158857 & 0.551699 \\
 OEselma Nonpolar Count & 9.445993 & 12.086764 & 12.375000 & 5.434184 & 0.575290 \\
 OEselma Ring Count & 1.811629 & 2.602073 & 2.652542 & 1.084616 & 0.598697 \\
 OEselma Atom Count & 15.766603 & 25.429675 & 25.002119 & 9.567522 & 0.606822 \\
 OEselma Max Rigid Chain & 4.269220 & 6.990578 & 7.162076 & 2.596076 & 0.608091 \\
 OEselma Bond Count & 16.980448 & 26.935092 & 26.652542 & 10.376671 & 0.611095 \\
 OEselma Rigid Frag Count & 3.579486 & 5.023363 & 4.927436 & 2.196631 & 0.613672 \\
 OEselma Max Flex Chain 1 & 2.645862 & 2.943565 & 2.967691 & 1.632688 & 0.617072 \\
 OEselma Max Flex Chain 3 & 1.623217 & 1.148954 & 1.181674 & 1.041896 & 0.641871 \\
 OEselma Max Flex Chain 2 & 1.948082 & 1.691916 & 1.758475 & 1.251045 & 0.642193 \\
 OEselma Pos Ioniz & 1.323273 & 1.011211 & 0.969280 & 0.850462 & 0.642695 \\
 OEselma Nitrogen Count & 2.861234 & 2.583797 & 2.566208 & 1.887779 & 0.659778 \\
 OEselma Nonpolar Count Per Mw & 0.020729 & 0.031652 & 0.033686 & 0.014295 & 0.689639 \\
 OEselma Aromatic Ring Count & 1.351165 & 1.607348 & 1.655720 & 0.990535 & 0.733097 \\
 OEselma Polar Count Per Mw & 0.009170 & 0.016298 & 0.015956 & 0.007268 & 0.792535 \\
"""

# %%
def process(ordering):
    a = ordering.split("\n")
    b = dict()
    for l in a:
        if l != '':
            b[l.split("&")[0]] = float(l.split("&")[4])
        
    return { k : b[k] for k in sorted(list(b.keys())) }

match = process(ols_oeselma)
compare = process(cnn_oeselma)

print(match)
print(compare)
# Out:
# {
#     ' OEselma Aromatic Ring Count ': 1.001529,
#     ' OEselma Atom Count ': 7.037158,
#     ' OEselma Bond Count ': 7.864136,
#     ' OEselma Bromine Count ': 0.067323,
#     ' OEselma Carbon Count ': 5.36407,
#     ' OEselma Clorine Count ': 0.298271,
#     ' OEselma Ertl Tpsa ': 49.051269,
#     ' OEselma Fluorine Count ': 0.495503,
#     ' OEselma Halogen Count ': 0.739378,
#     ' OEselma Hba ': 2.729655,
#     ' OEselma Hba Lipinski ': 3.011111,
#     ' OEselma Hbd ': 1.948421,
#     ' OEselma Hbd Lipinski ': 2.017538,
#     ' OEselma Iodine Count ': 0.07406,
#     ' OEselma Max Flex Chain 1 ': 1.515677,
#     ' OEselma Max Flex Chain 2 ': 1.116195,
#     ' OEselma Max Flex Chain 3 ': 0.932263,
#     ' OEselma Max Rigid Chain ': 2.869323,
#     ' OEselma Mol Volume 2D ': 157.692542,
#     ' OEselma Mw ': 104.350362,
#     ' OEselma Neg Ioniz ': 0.650857,
#     ' OEselma Nitrogen Count ': 1.709653,
#     ' OEselma Nonpolar Count ': 5.846501,
#     ' OEselma Nonpolar Count Per Mw ': 0.015105,
#     ' OEselma Npsa ': 92.760671,
#     ' OEselma Oxygen Count ': 2.389511,
#     ' OEselma Part Flex Chain ': 2.108171,
#     ' OEselma Phosphorous Count ': 0.224827,
#     ' OEselma Polar Count ': 3.004033,
#     ' OEselma Polar Count Per Mw ': 0.006958,
#     ' OEselma Pos Ioniz ': 0.821974,
#     ' OEselma Psa ': 52.274907,
#     ' OEselma Rigid Bond Count ': 6.257895,
#     ' OEselma Rigid Frag Count ': 2.000506,
#     ' OEselma Ring Count ': 1.149428,
#     ' OEselma Rot Bond Count ': 2.944185,
#     ' OEselma Silicon Count ': 0.00322,
#     ' OEselma Sulphur Count ': 0.442843,
#     ' OEselma Tsa ': 106.106942
# }
# {
#     ' OEselma Aromatic Ring Count ': 0.990535,
#     ' OEselma Atom Count ': 9.567522,
#     ' OEselma Bond Count ': 10.376671,
#     ' OEselma Bromine Count ': 0.036573,
#     ' OEselma Carbon Count ': 6.268767,
#     ' OEselma Clorine Count ': 0.163946,
#     ' OEselma Ertl Tpsa ': 50.082845,
#     ' OEselma Fluorine Count ': 0.267226,
#     ' OEselma Halogen Count ': 0.481674,
#     ' OEselma Hba ': 2.456341,
#     ' OEselma Hba Lipinski ': 3.158857,
#     ' OEselma Hbd ': 1.830414,
#     ' OEselma Hbd Lipinski ': 1.959633,
#     ' OEselma Iodine Count ': 0.02903,
#     ' OEselma Max Flex Chain 1 ': 1.632688,
#     ' OEselma Max Flex Chain 2 ': 1.251045,
#     ' OEselma Max Flex Chain 3 ': 1.041896,
#     ' OEselma Max Rigid Chain ': 2.596076,
#     ' OEselma Mol Volume 2D ': 204.456468,
#     ' OEselma Mw ': 119.0794,
#     ' OEselma Neg Ioniz ': 0.457865,
#     ' OEselma Nitrogen Count ': 1.887779,
#     ' OEselma Nonpolar Count ': 5.434184,
#     ' OEselma Nonpolar Count Per Mw ': 0.014295,
#     ' OEselma Npsa ': 98.622901,
#     ' OEselma Oxygen Count ': 2.135425,
#     ' OEselma Part Flex Chain ': 1.967213,
#     ' OEselma Phosphorous Count ': 0.118135,
#     ' OEselma Polar Count ': 3.074848,
#     ' OEselma Polar Count Per Mw ': 0.007268,
#     ' OEselma Pos Ioniz ': 0.850462,
#     ' OEselma Psa ': 54.736046,
#     ' OEselma Rigid Bond Count ': 5.730955,
#     ' OEselma Rigid Frag Count ': 2.196631,
#     ' OEselma Ring Count ': 1.084616,
#     ' OEselma Rot Bond Count ': 3.489025,
#     ' OEselma Silicon Count ': 0.001745,
#     ' OEselma Sulphur Count ': 0.288122,
#     ' OEselma Tsa ': 131.697137
# }

# %%
import numpy as np
sorted_descriptors = sorted(list(match.keys()))
OLS = np.asarray([ match[d] for d in sorted_descriptors ])
CNN = np.asarray([ compare[d] for d in sorted_descriptors ])
A = np.zeros((OLS.shape[0], 2))
A[:,0] = OLS
A[:,1] = CNN
with np.printoptions(7, suppress = True):
    print(A)
    
A = np.abs(A[:,0] - A[:,1])

B = dict()
for i, desc in enumerate(sorted_descriptors):
    B[desc] = A[i]
    
print(B)
# Out:
# [[  1.001529   0.990535]
#  [  7.037158   9.567522]
#  [  7.864136  10.376671]
#  [  0.067323   0.036573]
#  [  5.36407    6.268767]
#  [  0.298271   0.163946]
#  [ 49.051269  50.082845]
#  [  0.495503   0.267226]
#  [  0.739378   0.481674]
#  [  2.729655   2.456341]
#  [  3.011111   3.158857]
#  [  1.948421   1.830414]
#  [  2.017538   1.959633]
#  [  0.07406    0.02903 ]
#  [  1.515677   1.632688]
#  [  1.116195   1.251045]
#  [  0.932263   1.041896]
#  [  2.869323   2.596076]
#  [157.692542 204.456468]
#  [104.350362 119.0794  ]
#  [  0.650857   0.457865]
#  [  1.709653   1.887779]
#  [  5.846501   5.434184]
#  [  0.015105   0.014295]
#  [ 92.760671  98.622901]
#  [  2.389511   2.135425]
#  [  2.108171   1.967213]
#  [  0.224827   0.118135]
#  [  3.004033   3.074848]
#  [  0.006958   0.007268]
#  [  0.821974   0.850462]
#  [ 52.274907  54.736046]
#  [  6.257895   5.730955]
#  [  2.000506   2.196631]
#  [  1.149428   1.084616]
#  [  2.944185   3.489025]
#  [  0.00322    0.001745]
#  [  0.442843   0.288122]
#  [106.106942 131.697137]]
# {
#     ' OEselma Aromatic Ring Count ': 0.010993999999999837,
#     ' OEselma Atom Count ': 2.5303640000000005,
#     ' OEselma Bond Count ': 2.5125349999999997,
#     ' OEselma Bromine Count ': 0.030749999999999993,
#     ' OEselma Carbon Count ': 0.9046970000000005,
#     ' OEselma Clorine Count ': 0.134325,
#     ' OEselma Ertl Tpsa ': 1.0315760000000012,
#     ' OEselma Fluorine Count ': 0.228277,
#     ' OEselma Halogen Count ': 0.257704,
#     ' OEselma Hba ': 0.27331400000000006,
#     ' OEselma Hba Lipinski ': 0.1477459999999997,
#     ' OEselma Hbd ': 0.11800699999999997,
#     ' OEselma Hbd Lipinski ': 0.057905000000000095,
#     ' OEselma Iodine Count ': 0.04503,
#     ' OEselma Max Flex Chain 1 ': 0.11701099999999998,
#     ' OEselma Max Flex Chain 2 ': 0.13484999999999991,
#     ' OEselma Max Flex Chain 3 ': 0.10963299999999998,
#     ' OEselma Max Rigid Chain ': 0.273247,
#     ' OEselma Mol Volume 2D ': 46.763926,
#     ' OEselma Mw ': 14.729038000000003,
#     ' OEselma Neg Ioniz ': 0.192992,
#     ' OEselma Nitrogen Count ': 0.178126,
#     ' OEselma Nonpolar Count ': 0.4123169999999998,
#     ' OEselma Nonpolar Count Per Mw ': 0.00081,
#     ' OEselma Npsa ': 5.862229999999997,
#     ' OEselma Oxygen Count ': 0.25408600000000003,
#     ' OEselma Part Flex Chain ': 0.14095799999999992,
#     ' OEselma Phosphorous Count ': 0.106692,
#     ' OEselma Polar Count ': 0.07081499999999963,
#     ' OEselma Polar Count Per Mw ': 0.0003100000000000004,
#     ' OEselma Pos Ioniz ': 0.02848800000000007,
#     ' OEselma Psa ': 2.461139000000003,
#     ' OEselma Rigid Bond Count ': 0.5269400000000006,
#     ' OEselma Rigid Frag Count ': 0.19612499999999988,
#     ' OEselma Ring Count ': 0.06481199999999987,
#     ' OEselma Rot Bond Count ': 0.5448399999999998,
#     ' OEselma Silicon Count ': 0.0014750000000000002,
#     ' OEselma Sulphur Count ': 0.154721,
#     ' OEselma Tsa ': 25.590194999999994
# }

# %%
import pandas as pd
df = pd.DataFrame.from_dict(data = B, orient='index')
print(df.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &          0 \\
# \midrule
#  OEselma Aromatic Ring Count    &   0.010994 \\
#  OEselma Atom Count             &   2.530364 \\
#  OEselma Bond Count             &   2.512535 \\
#  OEselma Bromine Count          &   0.030750 \\
#  OEselma Carbon Count           &   0.904697 \\
#  OEselma Clorine Count          &   0.134325 \\
#  OEselma Ertl Tpsa              &   1.031576 \\
#  OEselma Fluorine Count         &   0.228277 \\
#  OEselma Halogen Count          &   0.257704 \\
#  OEselma Hba                    &   0.273314 \\
#  OEselma Hba Lipinski           &   0.147746 \\
#  OEselma Hbd                    &   0.118007 \\
#  OEselma Hbd Lipinski           &   0.057905 \\
#  OEselma Iodine Count           &   0.045030 \\
#  OEselma Max Flex Chain 1       &   0.117011 \\
#  OEselma Max Flex Chain 2       &   0.134850 \\
#  OEselma Max Flex Chain 3       &   0.109633 \\
#  OEselma Max Rigid Chain        &   0.273247 \\
#  OEselma Mol Volume 2D          &  46.763926 \\
#  OEselma Mw                     &  14.729038 \\
#  OEselma Neg Ioniz              &   0.192992 \\
#  OEselma Nitrogen Count         &   0.178126 \\
#  OEselma Nonpolar Count         &   0.412317 \\
#  OEselma Nonpolar Count Per Mw  &   0.000810 \\
#  OEselma Npsa                   &   5.862230 \\
#  OEselma Oxygen Count           &   0.254086 \\
#  OEselma Part Flex Chain        &   0.140958 \\
#  OEselma Phosphorous Count      &   0.106692 \\
#  OEselma Polar Count            &   0.070815 \\
#  OEselma Polar Count Per Mw     &   0.000310 \\
#  OEselma Pos Ioniz              &   0.028488 \\
#  OEselma Psa                    &   2.461139 \\
#  OEselma Rigid Bond Count       &   0.526940 \\
#  OEselma Rigid Frag Count       &   0.196125 \\
#  OEselma Ring Count             &   0.064812 \\
#  OEselma Rot Bond Count         &   0.544840 \\
#  OEselma Silicon Count          &   0.001475 \\
#  OEselma Sulphur Count          &   0.154721 \\
#  OEselma Tsa                    &  25.590195 \\
# \bottomrule
# \end{tabular}
