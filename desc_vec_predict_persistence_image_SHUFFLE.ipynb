# %%
from gtda.homology import EuclideanCechPersistence,VietorisRipsPersistence
from gtda.diagrams import PersistenceImage
from gtda.pipeline import Pipeline
from gtda.diagrams import Filtering

# %%
import tensorflow as tf
import gudhi as gd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils
import scipy.spatial as spatial
import json
from rich import print
from random import choice, sample
from tqdm.notebook import tqdm
from rdkit import Chem
from rdkit.Chem import Descriptors
from gc import collect
from pickle import load

with open("9701_cech_persistence_images_012_50x50.pickle", mode = "rb") as data:
    save_dict = load(data)
    
    test_molecules = save_dict["test_molecules"]
    test_data = save_dict["test_data"]
    
# %matplotlib inline
del save_dict
collect()
# Out:
# 4

# %% [markdown]
# # Extract descriptors
# (this can be done from rdkit or from the descriptor .csv)

# %%
df = pd.read_csv("data/Drugbank_some_descriptors.csv")
cntr = 0
for d in df:
    cntr += 1
print(cntr)
# Out:
# 126

# %% [markdown]
# ### Filter descriptors which are unavailable

# %%
descriptors = list()

# consider only descriptors which have few missing values and which are floating point
for d in df:
    if df[d].isna().sum() < 800 and df[d].dtype == np.float64:
        descriptors.append(d)

num_descriptors = len(descriptors)
print(descriptors)

test_smiles = set(test_molecules)

for i,d in enumerate(descriptors):
    avail_rows = df[np.logical_not(df[d].isna())]
    test_smiles = set(avail_rows["SMILES"]).intersection(test_smiles)

test_idxs = np.asarray(sorted([ test_molecules.index(t) for t in test_smiles ]))


test_molecules = np.asarray(test_molecules)
test_molecules = test_molecules[test_idxs]
test_data = test_data[test_idxs]
# Out:
# [
#     'ACD Descriptors;logP',
#     'ACD logD-logP;logP',
#     'MOE Descriptors;h_ema',
#     'MOE Descriptors;h_emd',
#     'MOE Descriptors;h_emd_c',
#     'MOE Descriptors;h_logp',
#     'MOE Descriptors;h_logs',
#     'MOE Descriptors;h_log_dbo',
#     'MOE Descriptors;h_log_pbo',
#     'MOE Descriptors;h_mr',
#     'OEselma Descriptors;bromine_count',
#     'OEselma Descriptors;carbon_count',
#     'OEselma Descriptors;clorine_count',
#     'OEselma Descriptors;ertl_tpsa',
#     'OEselma Descriptors;fluorine_count',
#     'OEselma Descriptors;hba',
#     'OEselma Descriptors;hba_lipinski',
#     'OEselma Descriptors;hbd',
#     'OEselma Descriptors;hbd_lipinski',
#     'OEselma Descriptors;halogen_count',
#     'OEselma Descriptors;iodine_count',
#     'OEselma Descriptors;max_flex_chain_1',
#     'OEselma Descriptors;max_flex_chain_2',
#     'OEselma Descriptors;max_flex_chain_3',
#     'OEselma Descriptors;max_rigid_chain',
#     'OEselma Descriptors;mol_volume_2d',
#     'OEselma Descriptors;mw',
#     'OEselma Descriptors;npsa',
#     'OEselma Descriptors;neg_ioniz',
#     'OEselma Descriptors;nitrogen_count',
#     'OEselma Descriptors;nonpolar_count',
#     'OEselma Descriptors;nonpolar_count_per_mw',
#     'OEselma Descriptors;rigid_frag_count',
#     'OEselma Descriptors;aromatic_ring_count',
#     'OEselma Descriptors;atom_count',
#     'OEselma Descriptors;bond_count',
#     'OEselma Descriptors;rigid_bond_count',
#     'OEselma Descriptors;ring_count',
#     'OEselma Descriptors;rot_bond_count',
#     'OEselma Descriptors;oxygen_count',
#     'OEselma Descriptors;psa',
#     'OEselma Descriptors;phosphorous_count',
#     'OEselma Descriptors;polar_count',
#     'OEselma Descriptors;polar_count_per_mw',
#     'OEselma Descriptors;pos_ioniz',
#     'OEselma Descriptors;silicon_count',
#     'OEselma Descriptors;sulphur_count',
#     'OEselma Descriptors;tsa',
#     'Ertl TPSA;Ertl TPSA',
#     'Exact Mass;Exact Mass',
#     'Heavy Atom Count;Heavy Atom Count',
#     'Molecular Volume (2D);Molecular Volume (2D)',
#     'Molecular Weight;Molecular Weight',
#     'NPSA;NPSA',
#     'PSA;PSA',
#     'Ring Count;Ring Count',
#     'Rotatable Bond Count;Rotatable Bond Count',
#     'AZlogD74;prediction',
#     'AZlogD74;sd_prediction',
#     'ChromlogD;prediction',
#     'ChromlogD;sd_prediction',
#     'ALogP',
#     'Mol Weight',
#     'Molar Refractivity',
#     'Polarizability',
#     'TPSA',
#     'Solubility DD Class;confidence',
#     'Solubility DD Class;credibility',
#     'SCScore;SCScore',
#     'AZlogD74 (NN);nearest_neighbours[]- GT similarity',
#     'AZlogD74 (NN);nearest_neighbours[]- GT measured',
#     'clogP;clogp',
#     'clogP;clogp_error',
#     'OEselma Descriptors;part_flex_chain'
# ]

# %% [markdown]
# ### Build numpy arrays of descriptors

# %%
collect()

test_labels = np.empty((test_data.shape[0], num_descriptors))

test_labels[:] = np.nan

for i,mol in enumerate(tqdm(test_molecules)):
    data_row = df.loc[df['SMILES'] == mol, descriptors ]
    data_vec = [ r.to_list()[-1] for l,r in data_row.items() ]
    test_labels[i,:] = np.asarray(data_vec)
# Out:
#   0%|          | 0/1802 [00:00<?, ?it/s]

# %%
model = tf.keras.models.load_model('saved_model/my_model')
# Out:
# 2022-01-08 17:39:21.832427: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-08 17:39:22.881157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6939 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
collect()
compare = np.zeros((test_data.shape[0], num_descriptors, 2))
compare[:,:,0] = test_labels
compare[:,:,1] = model.predict(test_data).reshape((test_data.shape[0],num_descriptors))

out_dict = dict()
out_dict["Descriptor"] = list()
out_dict["Average"] = list()
out_dict["Standard deviation"] = list()

for d in descriptors:
    out_dict["Descriptor"].append(d)
    out_dict["Average"].append(df[d].mean(skipna = True)) # population mean for this descriptor
    out_dict["Standard deviation"].append(df[d].std(skipna = True)) # population mean for this descriptor
    
out_dict["Test Average"] = compare[:,:,1].mean(axis = 0)
out_dict["Test Mean Absolute Error"] = np.abs(compare[:,:,0]-compare[:,:,1]).mean(axis = 0)
#out_dict["Predictability"] = out_dict["Average"]/out_dict["Test Mean Absolute Error"]

pd.set_option("display.max_rows", None, "display.max_columns", None)
out_df = pd.DataFrame(data = out_dict)
out_df
#print(out_df.to_latex())
# Out:
# 2022-01-08 17:39:23.516118: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 162180000 exceeds 10% of free system memory.
# 2022-01-08 17:39:23.640535: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 162180000 exceeds 10% of free system memory.
# 2022-01-08 17:39:25.186875: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8301
#                                            Descriptor    Average  \
# 0                                ACD Descriptors;logP   2.055326
# 1                                  ACD logD-logP;logP   2.053207
# 2                               MOE Descriptors;h_ema   8.864515
# 3                               MOE Descriptors;h_emd  12.580101
# 4                             MOE Descriptors;h_emd_c   6.492526
# ..                                                ...        ...
# 69  AZlogD74 (NN);nearest_neighbours[]- GT similarity   0.628486
# 70    AZlogD74 (NN);nearest_neighbours[]- GT measured   1.637720
# 71                                        clogP;clogp   1.655366
# 72                                  clogP;clogp_error  20.365517
# 73                OEselma Descriptors;part_flex_chain   4.829146
#
#     Standard deviation  Test Average  Test Mean Absolute Error
# 0             3.002862      2.363056                  1.990135
# 1             3.001606      2.167280                  1.994233
# 2             9.691163      7.450187                  2.837067
# 3            10.821464     11.510098                  4.215574
# 4             5.020204      6.005712                  1.964621
# ..                 ...           ...                       ...
# 69            0.201104     -0.116276                  0.751250
# 70            1.561973      1.347385                  1.375594
# 71            3.447059      1.522084                  2.222104
# 72           24.318937      9.325663                 17.864670
# 73            4.183248      5.019512                  1.846814
#
# [74 rows x 5 columns]

# %%
A = np.asarray([[1,2,3],[4,5,6],[7,8,9]])
A = np.asarray(sample([a for a in A], len(A)))
print(A)
# Out:
# [[4 5 6]
#  [1 2 3]
#  [7 8 9]]

# %%
collect()
compare = np.zeros((test_data.shape[0], num_descriptors, 2))
compare[:,:,0] = np.asarray(sample([vec for vec in test_labels], len(test_labels)))
compare[:,:,1] = model.predict(test_data).reshape((test_data.shape[0],num_descriptors))

out_dict = dict()
out_dict["Descriptor"] = list()
out_dict["Average"] = list()
out_dict["Standard deviation"] = list()

for d in descriptors:
    out_dict["Descriptor"].append(d)
    out_dict["Average"].append(df[d].mean(skipna = True)) # population mean for this descriptor
    out_dict["Standard deviation"].append(df[d].std(skipna = True)) # population mean for this descriptor
    
out_dict["Test Average"] = compare[:,:,1].mean(axis = 0)
out_dict["Test Mean Absolute Error"] = np.abs(compare[:,:,0]-compare[:,:,1]).mean(axis = 0)
#out_dict["Predictability"] = out_dict["Average"]/out_dict["Test Mean Absolute Error"]

pd.set_option("display.max_rows", None, "display.max_columns", None)
print(out_dict["Test Mean Absolute Error"].mean())
out_df = pd.DataFrame(data = out_dict)
out_df
# Out:
#                                            Descriptor     Average  \
# 0                                ACD Descriptors;logP    2.055326
# 1                                  ACD logD-logP;logP    2.053207
# 2                               MOE Descriptors;h_ema    8.864515
# 3                               MOE Descriptors;h_emd   12.580101
# 4                             MOE Descriptors;h_emd_c    6.492526
# 5                              MOE Descriptors;h_logp    6.583703
# 6                              MOE Descriptors;h_logs    9.838051
# 7                           MOE Descriptors;h_log_dbo   -3.836500
# 8                           MOE Descriptors;h_log_pbo    1.932621
# 9                                MOE Descriptors;h_mr    0.327136
# 10                  OEselma Descriptors;bromine_count    0.034856
# 11                   OEselma Descriptors;carbon_count   17.636929
# 12                  OEselma Descriptors;clorine_count    0.168629
# 13                      OEselma Descriptors;ertl_tpsa  102.704204
# 14                 OEselma Descriptors;fluorine_count    0.276967
# 15                            OEselma Descriptors;hba    5.812529
# 16                   OEselma Descriptors;hba_lipinski    6.789826
# 17                            OEselma Descriptors;hbd    2.674517
# 18                   OEselma Descriptors;hbd_lipinski    2.940744
# 19                  OEselma Descriptors;halogen_count    0.508902
# 20                   OEselma Descriptors;iodine_count    0.028450
# 21               OEselma Descriptors;max_flex_chain_1    2.943565
# 22               OEselma Descriptors;max_flex_chain_2    1.691916
# 23               OEselma Descriptors;max_flex_chain_3    1.148954
# 24                OEselma Descriptors;max_rigid_chain    6.990578
# 25                  OEselma Descriptors;mol_volume_2d  592.330629
# 26                             OEselma Descriptors;mw  373.328639
# 27                           OEselma Descriptors;npsa  307.642466
# 28                      OEselma Descriptors;neg_ioniz    0.539802
# 29                 OEselma Descriptors;nitrogen_count    2.583797
# 30                 OEselma Descriptors;nonpolar_count   12.086764
# 31          OEselma Descriptors;nonpolar_count_per_mw    0.031652
# 32               OEselma Descriptors;rigid_frag_count    5.023363
# 33            OEselma Descriptors;aromatic_ring_count    1.607348
# 34                     OEselma Descriptors;atom_count   25.429675
# 35                     OEselma Descriptors;bond_count   26.935092
# 36               OEselma Descriptors;rigid_bond_count   16.273575
# 37                     OEselma Descriptors;ring_count    2.602073
# 38                 OEselma Descriptors;rot_bond_count    6.681677
# 39                   OEselma Descriptors;oxygen_count    4.206029
# 40                            OEselma Descriptors;psa  106.494461
# 41              OEselma Descriptors;phosphorous_count    0.122751
# 42                    OEselma Descriptors;polar_count    6.059067
# 43             OEselma Descriptors;polar_count_per_mw    0.016298
# 44                      OEselma Descriptors;pos_ioniz    1.011211
# 45                  OEselma Descriptors;silicon_count    0.004239
# 46                  OEselma Descriptors;sulphur_count    0.289119
# 47                            OEselma Descriptors;tsa  414.138860
# 48                                Ertl TPSA;Ertl TPSA  102.704204
# 49                              Exact Mass;Exact Mass  372.828687
# 50                  Heavy Atom Count;Heavy Atom Count   25.426522
# 51        Molecular Volume (2D);Molecular Volume (2D)  592.330629
# 52                  Molecular Weight;Molecular Weight  373.328639
# 53                                          NPSA;NPSA  307.642466
# 54                                            PSA;PSA  106.494461
# 55                              Ring Count;Ring Count    2.602073
# 56          Rotatable Bond Count;Rotatable Bond Count    6.681677
# 57                                AZlogD74;prediction    0.608286
# 58                             AZlogD74;sd_prediction    0.729417
# 59                               ChromlogD;prediction    1.046476
# 60                            ChromlogD;sd_prediction    0.806016
# 61                                              ALogP    2.202912
# 62                                         Mol Weight  374.512520
# 63                                 Molar Refractivity   95.559089
# 64                                     Polarizability   37.783778
# 65                                               TPSA  107.810334
# 66                     Solubility DD Class;confidence    0.945031
# 67                    Solubility DD Class;credibility    0.577961
# 68                                    SCScore;SCScore    3.272166
# 69  AZlogD74 (NN);nearest_neighbours[]- GT similarity    0.628486
# 70    AZlogD74 (NN);nearest_neighbours[]- GT measured    1.637720
# 71                                        clogP;clogp    1.655366
# 72                                  clogP;clogp_error   20.365517
# 73                OEselma Descriptors;part_flex_chain    4.829146
#
#     Standard deviation  Test Average  Test Mean Absolute Error
# 0             3.002862      2.363056                  2.582372
# 1             3.001606      2.167280                  2.613927
# 2             9.691163      7.450187                  4.134048
# 3            10.821464     11.510098                  5.869087
# 4             5.020204      6.005712                  3.480841
# 5             4.622931      6.163813                  3.751346
# 6             5.975325      9.926347                  4.413926
# 7             3.066570     -2.558850                  2.690550
# 8             3.788166      1.209840                  2.639968
# 9             0.829737     -0.279508                  0.711346
# 10            0.265308     -0.043488                  0.150236
# 11           11.377305     18.235852                  9.281659
# 12            0.515279      0.661592                  0.675884
# 13           94.357347     84.685367                 50.642297
# 14            0.933018     -0.328199                  0.593924
# 15            4.799591      5.924236                  3.169285
# 16            5.725688      5.452643                  3.368762
# 17            3.482418      3.712697                  2.359979
# 18            3.595447      3.332135                  2.127614
# 19            1.127074      0.185581                  0.649401
# 20            0.287843     -0.139012                  0.214638
# 21            2.645862      2.618731                  1.902139
# 22            1.948082      1.752350                  1.506687
# 23            1.623217      2.022504                  1.550441
# 24            4.269220      5.941887                  3.295328
# 25          371.986946    569.183841                273.869109
# 26          227.821937    351.360673                162.248483
# 27          200.207940    304.976916                160.795168
# 28            1.108872     -0.083713                  0.726159
# 29            2.861234      1.777743                  1.983607
# 30            9.445993     12.784883                  8.551868
# 31            0.020729      0.377491                  0.344560
# 32            3.579486      5.044012                  2.531034
# 33            1.351165      2.250231                  1.353320
# 34           15.766603     26.223803                 11.759055
# 35           16.980448     28.498804                 13.284807
# 36           10.405612     18.309456                  8.989224
# 37            1.811629      2.756137                  1.624012
# 38            7.213711      6.771134                  4.697178
# 39            4.226225      4.434858                  2.900688
# 40          101.197251     86.599302                 53.186142
# 41            0.474829      0.187082                  0.285852
# 42            5.731492      6.255103                  3.652728
# 43            0.009170     -0.659979                  0.676637
# 44            1.323273      0.591411                  0.920471
# 45            0.108439     -0.227751                  0.233066
# 46            0.642512      0.045420                  0.515836
# 47          261.688962    401.619086                182.122888
# 48           94.357347     83.311942                 50.512542
# 49          227.548842    350.163905                162.203104
# 50           15.757548     25.654503                 11.546014
# 51          371.986946    568.952620                273.827813
# 52          227.821937    350.613247                162.158010
# 53          200.207940    305.779076                160.896945
# 54          101.197251     85.677175                 53.182098
# 55            1.811629      2.635975                  1.627876
# 56            7.213711      6.413813                  4.590869
# 57            3.226066      1.569402                  2.527788
# 58            0.652538      0.362211                  0.553530
# 59            3.779478      1.691216                  3.009410
# 60            0.649936     -0.062455                  0.882857
# 61            2.869296      2.522057                  2.330034
# 62          301.265463    351.369806                162.410007
# 63           74.060489     92.155992                 43.576993
# 64           29.516618     36.971605                 17.180863
# 65          133.333536     92.055496                 54.160250
# 66            0.055386      0.564550                  0.382356
# 67            0.263879      0.660939                  0.262215
# 68            1.067509      2.934440                  1.053070
# 69            0.201104     -0.116276                  0.750996
# 70            1.561973      1.347385                  1.384155
# 71            3.447059      1.522084                  2.837981
# 72           24.318937      9.325663                 20.294357
# 73            4.183248      5.019512                  3.343610
